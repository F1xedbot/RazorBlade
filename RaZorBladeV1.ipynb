# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 2.1.0+cu121
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 60.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 51.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch_geometric (pyproject.toml) ... done

# %%
import torch

# Load the dataset
loaded_dataset = torch.load('/content/drive/MyDrive/Colab_Notebooks/Datasets/reentrancy_data_list_smart_bugs.pt')

# %%
from torch.utils.data import random_split

# Assuming loaded_dataset is an instance of torch.utils.data.Dataset
# Specify the size of the validation set
validation_split = 0.2

# Calculate the sizes of the training and validation sets
num_data_points = len(loaded_dataset)
num_validation_points = int(validation_split * num_data_points)
num_train_points = num_data_points - num_validation_points

# Split the dataset
train_dataset, val_dataset = random_split(loaded_dataset, [num_train_points, num_validation_points])

# %%
len(train_dataset), len(val_dataset)
# Out:
# (2574, 643)

# %%
pos_count = 0
for data in train_dataset:
  if data.y == 1:
    pos_count += 1

print(pos_count)
print(len(train_dataset) - pos_count)
# Out:
# 1307
# 1267

# %%
train_dataset[0]
# Out:
# Data(x=[177, 48], edge_index=[2, 133], y=[1])

# %%
train_dataset[1]
# Out:
# Data(x=[144, 48], edge_index=[2, 115], y=[1])

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[18357, 48], edge_index=[2, 12488], y=[64], batch=[18357], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[15969, 48], edge_index=[2, 11788], y=[64], batch=[15969], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[20446, 48], edge_index=[2, 14017], y=[64], batch=[20446], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[16650, 48], edge_index=[2, 11801], y=[64], batch=[16650], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[20628, 48], edge_index=[2, 14661], y=[64], batch=[20628], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[21739, 48], edge_index=[2, 14680], y=[64], batch=[21739], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[20133, 48], edge_index=[2, 14116], y=[64], batch=[20133], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[19606, 48], edge_index=[2, 14053], y=[64], batch=[19606], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[17962, 48], edge_index=[2, 12575], y=[64], batch=[17962], ptr=[65])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[20541, 48], edge_index=[2, 14141], y=[64], batch=[20541], ptr=[65])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[18284, 48], edge_index=[2, 12002], y=[64], batch=[18284], ptr=[65])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[21690, 48], edge_index=[2, 14779], y=[64], batch=[21690], ptr=[65])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[20094, 48], edge_index=[2, 14356], y=[64], batch=[20094], ptr=[65])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[20274, 48], edge_index=[2, 13164], y=[64], batch=[20274], ptr=[65])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[17177, 48], edge_index=[2, 12260], y=[64], batch=[17177], ptr=[65])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[18463, 48], edge_index=[2, 12466], y=[64], batch=[18463], ptr=[65])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[16978, 48], edge_index=[2, 10826], y=[64], batch=[16978], ptr=[65])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[21352, 48], edge_index=[2, 14128], y=[64], batch=[21352], ptr=[65])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[19583, 48], edge_index=[2, 13371], y=[64], batch=[19583], ptr=[65])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[16478, 48], edge_index=[2, 12104], y=[64], batch=[16478], ptr=[65])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[17904, 48], edge_index=[2, 12887], y=[64], batch=[17904], ptr=[65])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[17529, 48], edge_index=[2, 12093], y=[64], batch=[17529], ptr=[65])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[21996, 48], edge_index=[2, 14130], y=[64], batch=[21996], ptr=[65])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[17762, 48], edge_index=[2, 12483], y=[64], batch=[17762], ptr=[65])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[19812, 48], edge_index=[2, 13651], y=[64], batch=[19812], ptr=[65])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[18754, 48], edge_index=[2, 13177], y=[64], batch=[18754], ptr=[65])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[18616, 48], edge_index=[2, 13180], y=[64], batch=[18616], ptr=[65])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[18906, 48], edge_index=[2, 12711], y=[64], batch=[18906], ptr=[65])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[17337, 48], edge_index=[2, 12828], y=[64], batch=[17337], ptr=[65])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[18082, 48], edge_index=[2, 12693], y=[64], batch=[18082], ptr=[65])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[19888, 48], edge_index=[2, 13559], y=[64], batch=[19888], ptr=[65])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[18436, 48], edge_index=[2, 12870], y=[64], batch=[18436], ptr=[65])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[19729, 48], edge_index=[2, 13278], y=[64], batch=[19729], ptr=[65])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[19741, 48], edge_index=[2, 12819], y=[64], batch=[19741], ptr=[65])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[19095, 48], edge_index=[2, 13034], y=[64], batch=[19095], ptr=[65])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[16872, 48], edge_index=[2, 12232], y=[64], batch=[16872], ptr=[65])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[18155, 48], edge_index=[2, 12625], y=[64], batch=[18155], ptr=[65])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[17381, 48], edge_index=[2, 12126], y=[64], batch=[17381], ptr=[65])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[16882, 48], edge_index=[2, 12818], y=[64], batch=[16882], ptr=[65])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[17684, 48], edge_index=[2, 12134], y=[64], batch=[17684], ptr=[65])
#
# Step 41:
# =======
# Number of graphs in the current batch: 14
# DataBatch(x=[3284, 48], edge_index=[2, 2553], y=[14], batch=[3284], ptr=[15])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool
from torch_geometric.nn import GraphConv


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GraphConv(48, hidden_channels)
        self.conv2 = GraphConv(hidden_channels, hidden_channels)
        self.conv3 = GraphConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 2)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)

        return x

model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GraphConv(48, 64)
#   (conv2): GraphConv(64, 64)
#   (conv3): GraphConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score

# %%
from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GCN(hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y.long())  # Convert data.y to long
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     all_preds = []
     all_labels = []

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         all_preds.extend(pred.cpu().numpy())
         all_labels.extend(data.y.cpu().numpy())
     accuracy = accuracy_score(all_labels, all_preds)
     recall = recall_score(all_labels, all_preds)
     f1 = f1_score(all_labels, all_preds)

     return accuracy, recall, f1


for epoch in range(1, 30):
    train()
    train_acc, train_recall, train_f1 = test(train_loader)
    test_acc, test_recall, test_f1 = test(test_loader)
    print(f'Epoch: {epoch} ...')
    print(f'Train Acc: {train_acc:.4f}, Recall: {train_recall:.4f}, F1: {train_f1:.4f}')
    print(f'Test Acc: {test_acc:.4f}, Recall: {test_recall:.4f}, F1: {test_f1:.4f}')
# Out:
# Epoch: 1 ...
# Train Acc: 0.6321, Recall: 0.8715, F1: 0.7064
# Test Acc: 0.6205, Recall: 0.8547, F1: 0.6747
# Epoch: 2 ...
# Train Acc: 0.7040, Recall: 0.7207, F1: 0.7120
# Test Acc: 0.6998, Recall: 0.7095, F1: 0.6852
# Epoch: 3 ...
# Train Acc: 0.7618, Recall: 0.7865, F1: 0.7703
# Test Acc: 0.7481, Recall: 0.7669, F1: 0.7370
# Epoch: 4 ...
# Train Acc: 0.7416, Recall: 0.8462, F1: 0.7689
# Test Acc: 0.7294, Recall: 0.8142, F1: 0.7348
# Epoch: 5 ...
# Train Acc: 0.7696, Recall: 0.7024, F1: 0.7559
# Test Acc: 0.7760, Recall: 0.6959, F1: 0.7410
# Epoch: 6 ...
# Train Acc: 0.7786, Recall: 0.8409, F1: 0.7941
# Test Acc: 0.7652, Recall: 0.8176, F1: 0.7622
# Epoch: 7 ...
# Train Acc: 0.7805, Recall: 0.6557, F1: 0.7521
# Test Acc: 0.7823, Recall: 0.6385, F1: 0.7297
# Epoch: 8 ...
# Train Acc: 0.7782, Recall: 0.8845, F1: 0.8019
# Test Acc: 0.7589, Recall: 0.8514, F1: 0.7648
# Epoch: 9 ...
# Train Acc: 0.8050, Recall: 0.8447, F1: 0.8148
# Test Acc: 0.7823, Recall: 0.8176, F1: 0.7756
# Epoch: 10 ...
# Train Acc: 0.8124, Recall: 0.7712, F1: 0.8067
# Test Acc: 0.7947, Recall: 0.7399, F1: 0.7684
# Epoch: 11 ...
# Train Acc: 0.7832, Recall: 0.8837, F1: 0.8054
# Test Acc: 0.7496, Recall: 0.8682, F1: 0.7615
# Epoch: 12 ...
# Train Acc: 0.8260, Recall: 0.7567, F1: 0.8153
# Test Acc: 0.7963, Recall: 0.7196, F1: 0.7648
# Epoch: 13 ...
# Train Acc: 0.8217, Recall: 0.8914, F1: 0.8354
# Test Acc: 0.7807, Recall: 0.8277, F1: 0.7765
# Epoch: 14 ...
# Train Acc: 0.8345, Recall: 0.8424, F1: 0.8379
# Test Acc: 0.7885, Recall: 0.8108, F1: 0.7792
# Epoch: 15 ...
# Train Acc: 0.8395, Recall: 0.7904, F1: 0.8334
# Test Acc: 0.7932, Recall: 0.7196, F1: 0.7621
# Epoch: 16 ...
# Train Acc: 0.8283, Recall: 0.8959, F1: 0.8412
# Test Acc: 0.7621, Recall: 0.8446, F1: 0.7657
# Epoch: 17 ...
# Train Acc: 0.8403, Recall: 0.7552, F1: 0.8277
# Test Acc: 0.7916, Recall: 0.6858, F1: 0.7519
# Epoch: 18 ...
# Train Acc: 0.8543, Recall: 0.8370, F1: 0.8537
# Test Acc: 0.7963, Recall: 0.8007, F1: 0.7835
# Epoch: 19 ...
# Train Acc: 0.8419, Recall: 0.7598, F1: 0.8299
# Test Acc: 0.8056, Recall: 0.6959, F1: 0.7672
# Epoch: 20 ...
# Train Acc: 0.8011, Recall: 0.9419, F1: 0.8278
# Test Acc: 0.7263, Recall: 0.8784, F1: 0.7471
# Epoch: 21 ...
# Train Acc: 0.8497, Recall: 0.7705, F1: 0.8388
# Test Acc: 0.7916, Recall: 0.6858, F1: 0.7519
# Epoch: 22 ...
# Train Acc: 0.8590, Recall: 0.7972, F1: 0.8517
# Test Acc: 0.7932, Recall: 0.7061, F1: 0.7586
# Epoch: 23 ...
# Train Acc: 0.8664, Recall: 0.9189, F1: 0.8747
# Test Acc: 0.8040, Recall: 0.8682, F1: 0.8031
# Epoch: 24 ...
# Train Acc: 0.8745, Recall: 0.8248, F1: 0.8697
# Test Acc: 0.8056, Recall: 0.7466, F1: 0.7795
# Epoch: 25 ...
# Train Acc: 0.8411, Recall: 0.7284, F1: 0.8232
# Test Acc: 0.7807, Recall: 0.6453, F1: 0.7304
# Epoch: 26 ...
# Train Acc: 0.8423, Recall: 0.7682, F1: 0.8318
# Test Acc: 0.7652, Recall: 0.6588, F1: 0.7209
# Epoch: 27 ...
# Train Acc: 0.8753, Recall: 0.8531, F1: 0.8742
# Test Acc: 0.7978, Recall: 0.7736, F1: 0.7789
# Epoch: 28 ...
# Train Acc: 0.8819, Recall: 0.8485, F1: 0.8795
# Test Acc: 0.8040, Recall: 0.7432, F1: 0.7774
# Epoch: 29 ...
# Train Acc: 0.8737, Recall: 0.8646, F1: 0.8743
# Test Acc: 0.7994, Recall: 0.7770, F1: 0.7810

# %%
# Save the model after training
torch.save(model.state_dict(), '/content/drive/MyDrive/Colab_Notebooks/GNN/CWE-118_gcn_model.pth')

# %%
reentrancy_check = GCN(hidden_channels=64)

# %%
reentrancy_check.load_state_dict(torch.load('/content/drive/MyDrive/Colab_Notebooks/GNN/reentrancy_gcn_model.pth'))
# Out:
# <All keys matched successfully>
